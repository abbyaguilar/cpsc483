# %% [markdown]
# <a href="https://colab.research.google.com/github/abbyaguilar/cpsc483/blob/main/lab0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MNIST Neural Network Lab
#
# Introductory TensorFlow/Keras exercise using the MNIST handwritten-digit dataset to practice preprocessing, dense neural networks, training, and evaluation.
#
# > **Coursework note:** This notebook is retained as part of my CPSC 483 Introduction to Machine Learning coursework. It includes instructional material and my completed exercises, and is presented as academic work rather than an independent production project.

# %%
import tensorflow as tf

# %%
tf.test.gpu_device_name()

# %%
# Importing libraries
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# Loading dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Preprocessing the data
train_images = train_images / 255.0
test_images  = test_images / 255.0
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# Building model
model = Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# Compiling the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Training the model
model.fit(train_images, train_labels, epochs=5, batch_size=32)

# Evaluating the model
test_loss,test_acc = model.evaluate(test_images, test_labels)
print('Test accuracy:', test_acc)
